# %% [markdown]
# # Jupyter notebooks and Python scripts
#
# ## Python basics

# %%
# variables and print

# %%
a

# %%
# lists and dictionary

# %%
# conditions and loops

# %%
# functions

# %% [markdown]
# <span style='background :yellow' > 1. Task: _Load the TUBAF logo from folder._ </span>

# %% [markdown]
# ## Markdown basics

# %% [markdown]
# titles, headlines

# %% [markdown]
# # Title
#
# ## Subtitle

# %% [markdown]
# paragraphs

# %% [markdown]
# enumerations
#
# + asdfa
# + agas
# + asdgasdg
# +

# %% [markdown]
# URLs and external images
#
# ![TU Bergakademie](https://www.google.com/imgres?q=tu%20freiberg&imgurl=https%3A%2F%2Fimage.jimcdn.com%2Fapp%2Fcms%2Fimage%2Ftransf%2Fdimension%3D940x10000%3Aformat%3Djpg%2Fpath%2Fsbc8dded4687b123c%2Fimage%2Fi44f499b614876ae3%2Fversion%2F1675182400%2Fdie-technische-universit%25C3%25A4t-bergakademie-freiberg-von-au%25C3%259Fen.jpg&imgrefurl=https%3A%2F%2Fwww.edgar-campus.de%2Funis-2%2Ftu-bergakademie-freiberg%2F&docid=RVhgGPjcKur2dM&tbnid=LPZSEVuUCzUvRM&vet=12ahUKEwiUnZf4iMyFAxVEzAIHHQfhBWoQM3oECGIQAA..i&w=940&h=611&hcb=2&ved=2ahUKEwiUnZf4iMyFAxVEzAIHHQfhBWoQM3oECGIQAA)

# %% [markdown]
# tables
#
# | Column 1 | COlumn 2 |
# |----------|----------|
# | aslödfkj | asdfjlasf|

# %% [markdown]
# latex code

# %% [markdown]
# <span style='background :yellow' > 2. Task: _Write the solution of a of the quadratic equation as Latex in Markdown._ </span>

# %% [markdown]
# $\alpha = \beta$

# %% [markdown]
# <span style='background :yellow' > 3. Task: _Investigate the use of tables in Markdown. Write down a short table with your name, study topic, ...._ </span>
